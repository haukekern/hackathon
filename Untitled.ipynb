# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline 
import os
from glob import glob

# %%
base_bone_dir = os.path.join('.')
age_df = pd.read_csv('C:\\hackathon\\LilGrabbies\\LilGrabbies_training.csv')
age_df = age_df[age_df.alter.notnull()]
age_df['path'] = age_df['id'].map(lambda x: 'C:\\hackathon\\LilGrabbies\\images\\{}.png'.format(x))
age_df['exists'] = age_df['path'].map(os.path.exists)
age_df['m'] = age_df['geschlecht'].map(lambda x: 1 if x == 'm' else 0)
print(age_df['exists'].sum(), 'images found of', age_df.shape[0], 'total')
boneage_mean = age_df['alter'].mean()
boneage_div = 2*age_df['alter'].std()
age_df['boneage_zscore'] = age_df['alter'].map(lambda x: (x-boneage_mean)/boneage_div)
age_df.dropna(inplace = True)
age_df.sample(3)
# Out:
# 10000 images found of 10000 total
#          id  alter geschlecht                                       path  \
# 8134  18134  150.0          m  C:\hackathon\LilGrabbies\images\18134.png
# 7976  17976  120.0          w  C:\hackathon\LilGrabbies\images\17976.png
# 2218  12218  180.0          m  C:\hackathon\LilGrabbies\images\12218.png
#
#       exists  m  boneage_zscore
# 8134    True  1        0.276094
# 7976    True  0       -0.089405
# 2218    True  1        0.641592

# %%
age_df['boneage_category'] = pd.cut(age_df['alter'], 10)
new_age_df = age_df.groupby(['boneage_category', 'm']).apply(lambda x: x.sample(400, replace = True)
                                                     ).reset_index(drop = True)
print('New Data Size:', new_age_df.shape[0], 'Old Size:', age_df.shape[0])
new_age_df[['alter', 'm']].hist(figsize = (10, 5))
# Out:
# New Data Size: 8000 Old Size: 10000
# array([[<AxesSubplot:title={'center':'alter'}>,
#         <AxesSubplot:title={'center':'m'}>]], dtype=object)

# %%
from sklearn.model_selection import train_test_split
train_df, valid_df = train_test_split(new_age_df, 
                                   test_size = 0.25, 
                                   random_state = 2018,
                                   stratify = new_age_df['boneage_category'])
print('train', train_df.shape[0], 'validation', valid_df.shape[0])
# Out:
# train 6000 validation 2000

# %%
from keras.preprocessing.image import ImageDataGenerator
IMG_SIZE = (384, 384)
core_idg = ImageDataGenerator(samplewise_center=True, 
                              samplewise_std_normalization=True, 
                              horizontal_flip = True, 
                              vertical_flip = False, 
                              height_shift_range = 0.1, 
                              width_shift_range = 0.1, 
                              rotation_range = 10, 
                              shear_range = 0.05,
                              fill_mode = 'nearest',
                              zoom_range=0.15)

# %%
train_gen = core_idg.flow_from_dataframe(train_df, 
                             x_col = 'path',
                            y_col = 'boneage_zscore', 
                            target_size = IMG_SIZE,
                             color_mode = 'grayscale',
                            batch_size = 64, class_mode="raw")

valid_gen = core_idg.flow_from_dataframe(valid_df, 
                             x_col = 'path',
                            y_col = 'boneage_zscore', 
                            target_size = IMG_SIZE,
                             color_mode = 'grayscale',
                            batch_size = 64, class_mode="raw")

test_X, test_Y = next(core_idg.flow_from_dataframe(
                               valid_df, 
                             x_col = 'path',
                            y_col = 'boneage_zscore', 
                            target_size = IMG_SIZE,
                             color_mode = 'grayscale',
                            batch_size = 500, class_mode="raw"))
# Out:
# Found 6000 validated image filenames.
# Found 2000 validated image filenames.
# Found 2000 validated image filenames.

# %%
t_x, t_y = next(train_gen)
fig, m_axs = plt.subplots(4, 4, figsize = (16, 16))
for (c_x, c_y, c_ax) in zip(t_x, t_y, m_axs.flatten()):
    c_ax.imshow(c_x[:,:,0], cmap = 'bone', vmin = -3, vmax = 3)
    c_ax.set_title('%2.0f months' % (c_y*boneage_div+boneage_mean))
    c_ax.axis('off')

# %%
# from keras.applications import MobileNetV2
from keras.applications.mobilenet import MobileNet
from keras.layers import GlobalAveragePooling2D, Dense, Dropout, Flatten, BatchNormalization
from keras.models import Sequential
base_mobilenet_model = MobileNet(input_shape =  t_x.shape[1:], 
                                 include_top = False, 
                                 weights = None)
bone_age_model = Sequential()
bone_age_model.add(BatchNormalization(input_shape = t_x.shape[1:]))
bone_age_model.add(base_mobilenet_model)
bone_age_model.add(BatchNormalization())
bone_age_model.add(GlobalAveragePooling2D())
bone_age_model.add(Dropout(0.5))
bone_age_model.add(Dense(1, activation = 'linear' )) # linear is what 16bit did
from keras.metrics import mean_absolute_error
def mae_months(in_gt, in_pred):
    return mean_absolute_error(boneage_div*in_gt, boneage_div*in_pred)

bone_age_model.compile(optimizer = 'adam', loss = 'mse',
                           metrics = [mae_months])

bone_age_model.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# batch_normalization_5 (Batch (None, 384, 384, 1)       4
# _________________________________________________________________
# mobilenet_1.00_384 (Model)   (None, 12, 12, 1024)      3228288
# _________________________________________________________________
# batch_normalization_6 (Batch (None, 12, 12, 1024)      4096
# _________________________________________________________________
# global_average_pooling2d_3 ( (None, 1024)              0
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 1024)              0
# _________________________________________________________________
# dense_3 (Dense)              (None, 1)                 1025
# =================================================================
# Total params: 3,233,413
# Trainable params: 3,209,475
# Non-trainable params: 23,938
# _________________________________________________________________

# %%
from keras.callbacks import ModelCheckpoint, LearningRateScheduler, EarlyStopping, ReduceLROnPlateau
weight_path="{}_weights.best2.hdf5".format('alter')

checkpoint = ModelCheckpoint(weight_path, monitor='val_loss', verbose=1, 
                             save_best_only=True, mode='min', save_weights_only = True)


reduceLROnPlat = ReduceLROnPlateau(monitor='val_loss', factor=0.8, patience=10, verbose=1, mode='auto', min_delta=0.0001, cooldown=5, min_lr=0.0001)
early = EarlyStopping(monitor="val_loss", 
                      mode="min", 
                      patience=5) # probably needs to be more patient, but kaggle time is limited
callbacks_list = [checkpoint, early, reduceLROnPlat]
# Out:
# Using TensorFlow backend.

# %%
train_gen.batch_size = 16
bone_age_model.fit_generator(train_gen, 
                                  validation_data = (test_X, test_Y), 
                                  epochs = 15, 
                                  callbacks = callbacks_list)
# Out:
# Epoch 1/15
# 375/375 [==============================] - 278s 742ms/step - loss: 0.5312 - mae_months: 48.2247 - val_loss: 1.9795 - val_mae_months: 96.9782
#
# Epoch 00001: val_loss improved from inf to 1.97952, saving model to alter_weights.best.hdf5
# Epoch 2/15
# 375/375 [==============================] - 271s 723ms/step - loss: 0.2934 - mae_months: 35.1924 - val_loss: 0.3207 - val_mae_months: 37.8050
#
# Epoch 00002: val_loss improved from 1.97952 to 0.32068, saving model to alter_weights.best.hdf5
# Epoch 3/15
# 375/375 [==============================] - 271s 723ms/step - loss: 0.2087 - mae_months: 29.6903 - val_loss: 0.6313 - val_mae_months: 57.8068
#
# Epoch 00003: val_loss did not improve from 0.32068
# Epoch 4/15
# 375/375 [==============================] - 270s 721ms/step - loss: 0.1744 - mae_months: 27.1750 - val_loss: 0.1648 - val_mae_months: 25.9809
#
# Epoch 00004: val_loss improved from 0.32068 to 0.16482, saving model to alter_weights.best.hdf5
# Epoch 5/15
# 375/375 [==============================] - 271s 722ms/step - loss: 0.1553 - mae_months: 25.5444 - val_loss: 0.1329 - val_mae_months: 23.6751
#
# Epoch 00005: val_loss improved from 0.16482 to 0.13295, saving model to alter_weights.best.hdf5
# Epoch 6/15
# 375/375 [==============================] - 271s 722ms/step - loss: 0.1411 - mae_months: 24.3103 - val_loss: 0.1313 - val_mae_months: 23.7846
#
# Epoch 00006: val_loss improved from 0.13295 to 0.13125, saving model to alter_weights.best.hdf5
# Epoch 7/15
# 375/375 [==============================] - 271s 722ms/step - loss: 0.1299 - mae_months: 23.2499 - val_loss: 0.1165 - val_mae_months: 22.1387
#
# Epoch 00007: val_loss improved from 0.13125 to 0.11648, saving model to alter_weights.best.hdf5
# Epoch 8/15
# 375/375 [==============================] - 271s 722ms/step - loss: 0.1173 - mae_months: 22.2747 - val_loss: 0.0937 - val_mae_months: 20.5406
#
# Epoch 00008: val_loss improved from 0.11648 to 0.09375, saving model to alter_weights.best.hdf5
# Epoch 9/15
# 375/375 [==============================] - 271s 722ms/step - loss: 0.1175 - mae_months: 22.1893 - val_loss: 0.0759 - val_mae_months: 17.5634
#
# Epoch 00009: val_loss improved from 0.09375 to 0.07593, saving model to alter_weights.best.hdf5
# Epoch 10/15
# 375/375 [==============================] - 271s 721ms/step - loss: 0.1116 - mae_months: 21.7739 - val_loss: 0.1988 - val_mae_months: 30.0097
#
# Epoch 00010: val_loss did not improve from 0.07593
# Epoch 11/15
# 375/375 [==============================] - 271s 722ms/step - loss: 0.1065 - mae_months: 21.2462 - val_loss: 0.2309 - val_mae_months: 32.0357
#
# Epoch 00011: val_loss did not improve from 0.07593
# Epoch 12/15
# 375/375 [==============================] - 271s 722ms/step - loss: 0.1041 - mae_months: 21.0164 - val_loss: 0.0515 - val_mae_months: 14.5412
#
# Epoch 00012: val_loss improved from 0.07593 to 0.05152, saving model to alter_weights.best.hdf5
# Epoch 13/15
# 375/375 [==============================] - 271s 723ms/step - loss: 0.0962 - mae_months: 20.2639 - val_loss: 0.0783 - val_mae_months: 18.3531
#
# Epoch 00013: val_loss did not improve from 0.05152
# Epoch 14/15
# 375/375 [==============================] - 271s 722ms/step - loss: 0.0925 - mae_months: 19.7948 - val_loss: 0.0794 - val_mae_months: 18.0054
#
# Epoch 00014: val_loss did not improve from 0.05152
# Epoch 15/15
#  63/375 [====>.........................] - ETA: 3:41 - loss: 0.0833 - mae_months: 18.7949
